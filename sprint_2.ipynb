# %% [markdown]
# ## **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут Валентин, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это не уместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩
# - детально изучены многие тонкости данных
# - здорово сделана предобработка данных
# - качественно исследованы данные
# - построено много интересных графиков
# - сделано много верных промежуточных выводов, основанных на полученных данных
#
# Твоего внимания требует:
# - небольшое исправление графиков
# - пересмотр выводов
# - исправление ошибки в коде
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, он бесплатный, но объемный(может уйти несколько месяцев):
# - У Тимофея Хирьянова есть [Плей-лист по алгоритмам на python](https://www.youtube.com/playlist?list=PLRDzFCPr95fK7tr47883DFUbm4GeOjjc0), это вроде просто видео-лекции, но в описании есть ссылка на лекции и практику, не стесняйся смотреть, преподаватель очень наглядно объясняет материал. На первых уроках задания могут показаться сложными, так как требует знания геометрии, не стесняйся проходить далее, будет проще)
#
# И вот доп ссылки на статьи по корреляции:
# - [Шкала Чеддока…](https://ekonometrik.ru/%D1%88%D0%BA%D0%B0%D0%BB%D0%B0-%D1%87%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0/), тут есть табличка по тому, как интерпретировать корреляцию
# - [Линейный коэффициент корреляции Пирсона](https://statanaliz.info/statistica/korrelyaciya-i-regressiya/linejnyj-koefficient-korrelyacii-pirsona/)
# - [Корреляция и регрессия](https://stepik.org/lesson/8086/step/1?unit=1365), это небольшой курс на степике, в котором можно пройти только нужные тебе блоки
# - [Корреляция и каузальность](https://pikabu.ru/story/korrelyatsiya_i_kauzalnost_5956601)
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Напиши здесь свои мысли и идеи по поводу комментария ревьюера.
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Спасибо, что есть оглавление в плагине toc. Теперь по проекту удобно перемещаться.
#
# Здорово, что во вступлении к твоему проекту есть
#
# - заголовок,
#
# - краткое описание проекта,
#
# - цель проекта
#
# Вступление станет лучше, если ты добавишь в него:
#
# - описание данных,
#
# - план работы
#
# Тогда получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Я вижу, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, что загружаешь все библиотеки в начале проекта. Так сложней случайно удалить ячейку с загрузкой нужной библиотеки и сделать код не работающим. А получатель отчета сразу поймет, какие библиотеки ты используешь и какие ему нужно установить для запуска проекта.
#
# </div>

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Все хорошо, хочу дать рекомендацию. При выводе df.head() можно увидеть, что часть столбцов заменилась на «...»
#
# Чтобы это поправить можно поправить настройки pandas:
#
# ```python
# pd.set_option('display.max_columns', 50)
# ```
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.shape
# Out:
# (23699, 22)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.hist(figsize=(15,20))
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Отлично, построены гистограммы по всем столбцам!
#
# </div>

# %% [markdown]
# Некоторые гистограммы похожи на распределение Пуассона, в других на первый взгляд вид распределения не ясен, скорее всего это связано с неоднородностью данных и выбросами

# %%
# Подсчет пропусков и визуализация процентного соотношения пропусков
display(pd.DataFrame(round((data.isna().mean()*100),2).sort_values(ascending=False), columns=['NaNs, %']).style.format(
    '{:.2f}').background_gradient('bwr'))
display(data.isna().sum().sort_values(ascending=False))
empty = data.isna().sum().sum() / (len(data) * len(data.columns))
print('Процент пропусков: {:.0%}'.format(empty))
# Out:
# <style  type="text/css" >
# #T_fa670_row0_col0{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_fa670_row1_col0{
#             background-color:  #ff8080;
#             color:  #000000;
#         }#T_fa670_row2_col0{
#             background-color:  #ff9a9a;
#             color:  #000000;
#         }#T_fa670_row3_col0{
#             background-color:  #ffe6e6;
#             color:  #000000;
#         }#T_fa670_row4_col0{
#             background-color:  #e0e0ff;
#             color:  #000000;
#         }#T_fa670_row5_col0,#T_fa670_row6_col0,#T_fa670_row7_col0,#T_fa670_row8_col0{
#             background-color:  #8686ff;
#             color:  #000000;
#         }#T_fa670_row9_col0{
#             background-color:  #4c4cff;
#             color:  #f1f1f1;
#         }#T_fa670_row10_col0{
#             background-color:  #3636ff;
#             color:  #f1f1f1;
#         }#T_fa670_row11_col0{
#             background-color:  #2e2eff;
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что изучено соотношение пропущенных данных, это отличная практика.
#
# </div>

# %% [markdown]
# Общее количество пропусков 19%. Пропуски в столбцах <u>is_apartment и balcony</u> могли возникнуть из-за того, что поле было не обязательным, и пользователи оставляли его пустым, однако полностью исключить техническую ошибку нельзя.<br>
# Большая группа пропусков связана с данными, получеными из картографии: <br>
#  <u>parks_nearest и ponds_nearest, airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000</u>. <br>
# Более того, процент пропусков в столбцах <u>airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000</u> почти одинаковый, что может быть связано с общей проблемой при загрузке данных.

# %%
# Получение общей информации о данных в колонках (с колличественными переменными) data
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# **Вывод**<br>
# В колонках <u>ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name, distance_airport, distance_city_center, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition </u> есть пропуски.<br>
# На первый взгляд, аномалиями могут быть: большая высота потолков, площадь кухни в 112 кв., и др.
# Необходимо проанализировать каждый слолбец и проверить, какие значения являются аномалией и устранить их. <br>
# Также, имеются проблемы с типом данных, логично поменять тип данных на "int" в <u>"floors_total", "balcony", "parks_around3000", "ponds_around3000"</u> поскольку количество этажей, дней и балконов, парков и водоёмов не может быть нецелочисленным значением.<br>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хороший, красиво оформленный, промежуточный вывод, сразу понятно, что будет далее в предобработке.
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
# Выведем названия столбцов
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Приведем названия столбцов в единый вид.

# %%
#Изменение названия столбца
data = data.rename(columns={'cityCenters_nearest': 'city_center_nearest'})

# %%
#Замена формата даты и времени
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Приведение к типу данных лучше вынести в отдельный блок, чтобы были видны преобразования сразу по всем колонкам в одном месте.
#
# </div>

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <span style="color:#DE3163"> **Работа с пропусками**</span>

# %% [markdown]
# <span style="color:blue"> **Столбец balcony**</span>

# %%
# Посмотрим количество значений в колонке balcony
data['balcony'].value_counts(dropna=False)
# Out:
# NaN    11519
# 1.0     4195
# 0.0     3758
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# Заменим пустые значения в столбце "балкон", предположив, что пропущенные значения говорят об отсутствии баклона или необязательном поле при заполнении.

# %%
#Замена пропусков в столбце balcony нулями
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <span style="color:blue"> **Столбец is_apartment**</span>

# %%
# Посмотрим количество значений в колонке is_apartment
data['is_apartment'].value_counts(dropna=False)
# Out:
# NaN      20924
# False     2725
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Как было отмечено ранеее, пропуски в в данном столбце могут свидетельствовать, как об ошибке в данных или аномалии,
# так и об отсутствии информаци, например, в данном случае, скорее всего, поле в объявлении было необязательным к заполению.
# Таким образом, подставлять значения в этот столбец было бы неправильно.
# Заполним столбец значениями False и переведём формат из object в bool.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['is_apartment'] = data['is_apartment'].astype('bool')

# %%
#Проверим количество пропусков 
display(data['is_apartment'].isna().sum())
# Out:
# 0

# %% [markdown]
# <span style="color:blue"> **Столбец floors_total**</span>

# %%
# Посмотрим на данные в столбце floors_total
data['floors_total'].hist(bins=50, range=(0, 60), figsize=(15, 5)) 
plt.title("Этажность")
plt.ylabel("Количество квартир")
plt.xlabel("Количество этажей")
plt.show()
display(data['floors_total'].describe())
data['floors_total'].isna().sum()
# Out:
# count    23613.000000
# mean        10.673824
# std          6.597173
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64
# 86

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Здорово, что ты используешь range, так нагляднее.
#
# </div>

# %% [markdown]
# Общее количество пропусков в данных столбцах невелико, поэтому их можно удалить

# %%
#Удаляем данные с пропусками в столбцах floors_total 
data=data.dropna(subset=['floors_total'])

# %%
data['floors_total'].max(), data['floors_total'].min()
# Out:
# (60.0, 1.0)

# %%
#Проверим не являются ли данные аномальными
data[['floors_total', 'locality_name']].query('floors_total > 35')
# Out:
#        floors_total    locality_name
# 397            36.0  Санкт-Петербург
# 2253           60.0        Кронштадт
# 5807           36.0  Санкт-Петербург
# 11079          36.0  Санкт-Петербург
# 16731          52.0  Санкт-Петербург
# 16934          37.0  Санкт-Петербург

# %% [markdown]
# |floors_total	| locality_name |
# | --- | --- |
# | 397 |  36	Санкт-Петербург |
# | 871  |   35	Санкт-Петербург |
# |1060   |  35	Санкт-Петербург |
# | 2253    | 60 Кронштадт |
#
# Большое количество этажей в домах СПб выглядит нормальным, однако 60-этажное здание Кронштадта вызывает вопросы.
# По ссылке из [Википедии](https://ru.wikipedia.org/wiki/Морской_Никольский_собор_(Кронштадт)) видим, что самое высокое здание Морской Никольский собор ~ 70 м., это около 23-24 этажей, возможно в таблице опечатка, исправим на 6.

# %%
data.loc[data['floors_total'] == 60, 'floors_total'] = 6
data[['floors_total', 'locality_name']].query('floors_total > 35')
# Out:
#        floors_total    locality_name
# 397            36.0  Санкт-Петербург
# 5807           36.0  Санкт-Петербург
# 11079          36.0  Санкт-Петербург
# 16731          52.0  Санкт-Петербург
# 16934          37.0  Санкт-Петербург

# %% [markdown]
# <span style="color:blue"> **Столбец floor**</span>

# %%
# В столбце floor пропусков нет, посмотрим есть ли аномалии 
display(data['floor'].describe())
display(data['floor'].value_counts())
data['floor'].hist(bins=33, range=(0, 35), figsize=(15, 5)) 
plt.show()
# Out:
# count    23613.000000
# mean         5.877313
# std          4.873539
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64
# 2     3366
# 3     3069
# 1     2914
# 4     2794
# 5     2617
# 6     1296
# 7     1214
# 8     1075
# 9     1046
# 10     684
# 11     520
# 12     520
# 13     376
# 15     340
# 14     335
# 16     315
# 17     226
# 18     175
# 19     144
# 21     121
# 22     112
# 20     108
# 23      99
# 24      61
# 25      46
# 26      24
# 27      10
# 28       1
# 29       1
# 32       1
# 30       1
# 33       1
# 31       1
# Name: floor, dtype: int64

# %%
# Добавим столбец с этажом квартиры
data['floor_position'] = ['другой'] * len(data)
data.loc[data['floor'] == 1, 'floor_position'] = 'первый'
data.loc[data['floor'] == data['floors_total'], 'floor_position'] = 'последний'
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1             NaN          11.0         18.6      1         False  ...
# 2             NaN           5.0         34.3      4         False  ...
# 3             NaN          14.0          NaN      9         False  ...
# 4            3.03          14.0         32.0     13         False  ...
#
#    balcony    locality_name  airports_nearest  city_center_nearest  \
# ...

# %% [markdown]
# Аномалий не найдено.

# %% [markdown]
# <span style="color:blue"> **Столбец kitchen_area**</span>

# %% [markdown]
# Пропуски в kitchen_area (10%) возможно связаны как с технической ошибкой, так и  с квартирами-студиями или открытой планировкой.
# Необходимо проверить сколько значений заполнено и какая медиана,
# а также общее число сколько студий и открытых планировок в данных.

# %%
#Посмотрим количество студий и откртытых планировок в датасете
display(data['open_plan'].value_counts(dropna=False))
data['studio'].value_counts(dropna=False)
# Out:
# False    23546
# True        67
# Name: open_plan, dtype: int64
# False    23467
# True       146
# Name: studio, dtype: int64

# %%
# Построим сводную таблицу с подсчетом медианы и количества значений кухонной площади для студий и откртых планировок
display(data.pivot_table(index='studio', values='kitchen_area', aggfunc=('count', 'median')))
data.pivot_table(index='open_plan', values='kitchen_area', aggfunc=('count', 'median'))
# Out:
#         count  median
# studio
# False   21382     9.1
# True        0     NaN
#            count  median
# open_plan
# False      21382     9.1
# True           0     NaN

# %% [markdown]
# Как и предполагалось, ни в квартирах с открытыми планировками, ни в студиях площадь кухни не указана.<br>
# Заполним пропуски в кухонной площади для открытых планировок и студий нулями.

# %%
# Заполним нулями площадь кухни у студий и открытых планировок
data.loc[data['studio'],'kitchen_area']=0
data.loc[data['open_plan'],'kitchen_area']=0

# %%
# Посмотрим на оставшиеся пропуски в столбце kitchen_area 
plt.show(data['kitchen_area'].hist(bins=30))
data['kitchen_area'].isna().sum()
# Out:
# 2018

# %% [markdown]
# Далее проверим, можно ли использовать связь между общей площадью квартир и площадью кухни для заполнения оставшихся 2009 пропусков.
# Построим диаграмму зависимости.

# %%
data.plot(x='kitchen_area', y='total_area', kind='scatter', grid=True, figsize=(15, 5))
plt.title("Отношение площади кухни к общей площади")
plt.ylabel("Общая площадь")
plt.xlabel("Площадь кухни")
plt.show()
print('Корреляция: {:.1%}'.format(data['kitchen_area'].corr(data['total_area'])))
# Out:
# Корреляция: 61.1%

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Обрати внимание на то, что на данном графике все точки слились в большое пятно.
#
# Повтори, пожалуйста, еще раз в спринт «Исследовательский анализ данных» тему «Взаимосвязь данных» урок «Корреляция» и попробуй добавить параметр прозрачности.
#
# Поправь, пожалуйста, тут и на всех подобных графиках ниже.
#
#
# </div>

# %% [markdown]
# Связь нельзя назвать четко линейной, но, тем не менее, коэффициент 61% позволяте предположить,
# что она существует и можно заполнить пропуски в столбце площади кухонь,
# используя данные total_area

# %%
#Вычислим среднее значение жилой площади и используем метод fillna(), 
#чтобы заменить пропущенные значения в этом столбце и сразу проверим, остались ли пропуски.
kitchen_area_mean = (data['kitchen_area'] / data['total_area']).mean()
data['kitchen_area'] = data['kitchen_area'].fillna(round((data['total_area'] * kitchen_area_mean), 2))
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Пропуски заполнены корректно 😃
#
# </div>

# %% [markdown]
# <span style="color:blue"> **Столбец total_area**</span>

# %%
# В столбце total_area пропусков нет, посмотрим есть ли аномалии 
data['total_area'].describe()
# Out:
# count    23613.000000
# mean        60.340678
# std         35.648988
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.800000
# max        900.000000
# Name: total_area, dtype: float64

# %%
display(data[['total_area']].query('total_area > 500'))
# Out:
#        total_area
# 3117        631.0
# 4237        517.0
# 5358        590.0
# 8018        507.0
# 12859       631.2
# 15651       618.0
# 19540       900.0

# %%
data.boxplot(column='total_area', figsize=(15,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Аномальными выбросами выглядит общая площадь > 600м.<br>
# Также нужно проверить, что сумма жилой площади и площади кухни не превышает общую площадь.

# %%
#Выведем на экран, есть ли несоответствия.
print('Несоответствие суммы: {}'.format(
    data.query('total_area < (kitchen_area + living_area)')['last_price'].count()
))
#И сразу их найдем
df = data.query('total_area < (kitchen_area + living_area)')[['total_area', 'kitchen_area', 'living_area']]
df['difference'] = df['total_area'] - df['kitchen_area'] - df['living_area']
df.sort_values(by='difference', ascending=True)
# Out:
# Несоответствие суммы: 95
#        total_area  kitchen_area  living_area  difference
# 7857        230.0         42.66       220.00      -32.66
# 7239         90.0         43.40        76.40      -29.80
# 4366         47.7         28.20        39.80      -20.30
# 6802         69.0         25.00        64.00      -20.00
# 11579        33.0         26.00        26.00      -19.00
# ...           ...           ...          ...         ...
# 6432         23.0          4.27        19.00       -0.27
# 19904        12.0          2.23        10.00       -0.23
# 7680         38.8          6.00        33.00       -0.20
# 11179        33.0          6.12        27.06       -0.18
# 20651        24.5          4.54        20.00       -0.04
#
# [95 rows x 4 columns]

# %% [markdown]
# Найдено 103 несоответствия

# %%
#Заменим данные в total_area на сумму жилой площади и площади кухни.
data.loc[data['total_area'] < (data['kitchen_area'] + data['living_area']), 'total_area'] = \
data['kitchen_area'] + data['living_area']

print('Несоответствие суммы: {}'.format(
    data.query('total_area < (kitchen_area + living_area)')['last_price'].count()
))
# Out:
# Несоответствие суммы: 0

# %% [markdown]
# <span style="color:blue"> **Столбец ceiling_height**</span>

# %%
#Посмотрим на данные столбца 'ceiling_height'

data.boxplot(column='ceiling_height', figsize=(15,10));
plt.ylim(0,)
# Out:
# (0.0, 104.95)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Рад, что ты используешь ylim, так понятнее.
#
# </div>

# %% [markdown]
# Диаграмма показывает, что медиана значений находится на уровне около 2,5 м., однако есть и выбросы данных, посмотрим описание столбца

# %%
data['ceiling_height'].describe()
# Out:
# count    14495.000000
# mean         2.771495
# std          1.261445
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
#Проверим количество пропусков в столбце 'ceiling_height'
data['ceiling_height'].isna().sum()
# Out:
# 9118

# %%
#Проверим есть ли корреляция 'ceiling_height' / 'total_area'
data.plot(x='ceiling_height', y='total_area', kind='scatter', grid=True, figsize=(15, 5))
plt.title("Корреляция 'ceiling_height' / 'total_area'")
plt.ylabel("'total_area'")
plt.xlabel("'ceiling_height'")
plt.show()
print('Корреляция: {:.1%}'.format(data['ceiling_height'].corr(data['total_area'])))
# Out:
# Корреляция: 9.6%

# %%
#Проверим есть ли корреляция 'ceiling_height' / 'city_center_nearest'
data.plot(x='ceiling_height', y='city_center_nearest', kind='scatter', grid=True, figsize=(15, 5))
plt.title("Корреляция 'ceiling_height' / 'city_center_nearest'")
plt.ylabel("'city_center_nearest'")
plt.xlabel("'ceiling_height'")
plt.show()
print('Корреляция: {:.1%}'.format(data['ceiling_height'].corr(data['city_center_nearest'])))
# Out:
# Корреляция: -9.2%

# %%
(data
 .plot(x='city_center_nearest', y='last_price', kind='hexbin',gridsize=20, figsize=(8, 6), sharex=False, grid=True)
).set_title('Зависимость цены от удаленности от центра')
plt.ylabel('Цена')
plt.xlabel('Расстояние')
plt.show()

# %% [markdown]
# Есть небольшая корреляция общей площади квартиры и высоты потолка, однако, достаточно ли ее чтобы заполнять столбцы?
# При медианном значении в 2.65 в столбце отмечаются аномальные значения в 1 м. и 100 м., и 9084 пропуска <br>
# Посмотрим на количество пропущенных значений и высоту потолков в диапазане от 2 до 5 м. и посмотрим также, есть ли зависимость высоты потолка от этажа или этажности здания.

# %%
# Построим гистограмму в диапазоне от 1.5 метров, до 5 метров
data['ceiling_height'].hist(range=(2.5,3))
plt.show()

# %% [markdown]
# Видим, что больше всего квартир с высотой потолков между 2.5м. и 3м.

# %%
display(len(data.query('2 < ceiling_height < 5')))
display(len(data.query('ceiling_height > 5')))
display(len(data.query('ceiling_height < 2')))
print(len(data.query('2 < ceiling_height < 5')) + data['ceiling_height'].isna().sum())
# Out:
# 14444
# 36
# 3
# 23562

# %% [markdown]
# Посмотрим есть ли зависимоть между высотой потолков, общей этажностью и этажом квартиры

# %%
display(data['ceiling_height'].corr(data['floors_total']))
display(data['ceiling_height'].corr(data['floor']))
# Out:
# -0.028847422265718178
# -0.01180587244532528

# %% [markdown]
# Зависимости нет и всего 39 значений не попадают в выбранный диапазон высоты потолков от 2 до 5 м.
# Заменим пропуски и аномальные показатели в высоте потолка медианным показателем.

# %%
height = data['ceiling_height'].median()
data['ceiling_height'] = data['ceiling_height'].fillna(value=height)
data.loc[data['ceiling_height'] > 5, 'ceiling_height'] = height
data.loc[data['ceiling_height'] < 2, 'ceiling_height'] = height
print(height)
# Out:
# 2.65

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, верно обработаны выбивающиеся значения)
#
# </div>

# %% [markdown]
# <span style="color:blue"> **Столбец living_area**</span>

# %% [markdown]
# Далее проверим, можно ли использовать связь между общей площадью квартир и жилой площадью для заполнения пропусков.
# Для этого построим диаграмму зависимости.

# %%
data.plot(x='living_area', y='total_area', kind='scatter', grid=True, figsize=(15, 5))
plt.title("Отношение жилой площади к общей")
plt.ylabel("Общая площадь")
plt.xlabel("Жилая площадь")
plt.show()
print('Корреляция: {:.1%}'.format(data['living_area'].corr(data['total_area'])))
# Out:
# Корреляция: 94.0%

# %% [markdown]
# По графику и коэффициенту корреляции Пирсона (94.0%) можно сделать вывод, что существует линейная связь между показателями.
# Таким образом, используем данные столбца total_area для заполнения пропусков в living_area.

# %%
#Вычислим среднее значение жилой площади и используем метод fillna(), 
#чтобы заменить пропущенные значения в этом столбце и сразу проверим, остались ли пропуски.
living_area_mean = (data['living_area'] / data['total_area']).mean()
data['living_area'] = data['living_area'].fillna(round((data['total_area'] * living_area_mean), 2))
data['living_area'].isna().sum()
# Out:
# 0

# %%
data['living_area'].max(), data['living_area'].min()
# Out:
# (409.7, 2.0)

# %% [markdown]
# <span style="color:blue"> **Столбец last_price**</span>

# %%
#Посмотрим общую информацию столбца
display(data['last_price'].describe())
display(data['last_price'].isna().sum())
display(data['last_price'].value_counts())
data['last_price'] = data['last_price'].astype(int)
# Out:
# count    2.361300e+04
# mean     6.540555e+06
# std      1.090172e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.799000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64
# 0
# 4500000.0     341
# 3500000.0     291
# 4300000.0     260
# 4000000.0     260
# 4200000.0     259
#              ...
# 86738800.0      1
# 10430000.0      1
# 9917600.0       1
# 3180500.0       1
# 4386000.0       1
# Name: last_price, Length: 2939, dtype: int64

# %%
#Проверим аномально низкие цены
data[['last_price']].query('last_price < 100000')
# Out:
#       last_price
# 8793       12190

# %% [markdown]
# Цена в 12190 явная аномалия, удалим ее

# %%
data = data[data['last_price'] > 13000]

# %% [markdown]
# <span style="color:blue"> **Столбцы parks_around3000 и ponds_around3000**</span>

# %% [markdown]
# Пропуски количества парков и водоёмов можно считать
# фактическим отсутствием парков и водоёмов в радиусе 3000 м от недвижимости.
# Заменим пропущенные значения на нули.

# %%
#Заменим пропущенные значения на 0 методом fillna()
data['parks_around3000'] = data['parks_around3000'].fillna(0)
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)

#Проверим, что нет аномальных значений
display(data['parks_around3000'].unique())
data['ponds_around3000'].unique()
# Out:
# /tmp/ipykernel_458/3883062772.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['parks_around3000'] = data['parks_around3000'].fillna(0)
# /tmp/ipykernel_458/3883062772.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
# array([1., 0., 2., 3.])
# array([2., 0., 3., 1.])

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Выше в 53 ячейке ты фильтруешь строки, и не применяешь метод [reset_index](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html).
#
# В python ссылочная модель хранения данных. Оператор «=»(присваивания) связывает переменную и ссылку на ячейку памяти. Соответственно, когда ты присваиваешь новой переменной отфильтрованные данные по старой переменной, python просто прописывает ссылки на старые данные, а не создает новую ячейку памяти. Это опасно тем, что можно что-то поменять в новой переменной и поменяется старая переменная. Пример ниже в коде. Чтобы этого избежать можно использовать метод .copy(), он применим ко многим структурам данных, в том числе и к df, но к df лучше применять reset_index.
#
# </div>

# %%
# Код ревьюера

# Вот пример на массивах, но с df похожая ситуация может произойти
list_1 = [1, 2, 3]
list_2 = list_1
list_2[0] = 4

print('По идее list_1 не должен меняться, но list_1 =', list_1)

list_1 = [1, 2, 3]
list_2 = list_1.copy()
list_2[0] = 4

print('list_1 не изменился, list_1 =', list_1)
# Out:
# По идее list_1 не должен меняться, но list_1 = [4, 2, 3]
# list_1 не изменился, list_1 = [1, 2, 3]

# %% [markdown]
# <span style="color:blue"> **Столбец locality_name**</span>

# %%
# Посмотрим уникальные значения в столбце locality_name
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Сразу очевидно,что есть неявные дубликаты, буквы "е" и "ё",
# городской поселок - поселок городского типа, их необходимо удалить.

# %%
display(data['locality_name'].unique())

# После удаления

display(len(sorted_locality_name))
display(sorted_locality_name)
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Нет переменной sorted_locality_name
#
# Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
#
# </div>

# %%
# Посчитаем уникальные значения в столбце locality_name до замены букв
print('Количество до замены', len(set(data['locality_name'])))
# Замена букв 
data['locality_name'] = data['locality_name'].str.replace('ё','е')
# Замена городской поселок на поселок городского типа
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')
# Посчитаем уникальные значения в столбце locality_name после замен
print('Количество после замены',len(set(data['locality_name'])))

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что тобою было замечено разное написание слова «посёлок» и было принято решение это исправить 😃
#
# </div>

# %%
def groupping_locality(line):
    if pd.isnull(line):
        return 'Unknown'
    elif 'деревня' in line:
        return 'деревня'
    elif 'поселок' in line:
        return 'поселок'
    elif 'село' in line:
        return 'село'
    elif 'товарищество' in line:
        return 'товарищество'
    elif 'Санкт-Петербург' in line:
        return 'СПб'
    return 'город'


# Создадим столбец locality_group
data['locality_group']=data['locality_name'].apply(groupping_locality)
data.head(10)

# %%
value = 'н/а'
data['locality_name'] = data['locality_name'].fillna(value)
display(data['locality_name'].value_counts())
print('Количество пропущенных значений', data['locality_name'].isna().sum())

# %% [markdown]
# <span style="color:blue"> **Столбец rooms**</span>

# %%
#Проверим количество пропусков в столбце 'rooms'
data['rooms'].isna().sum()

# %%
display(data['rooms'].value_counts())
data['rooms'].hist(range=(1,10))
plt.show()

# %% [markdown]
# Видим 194 объекта со значением 0, возможно, являются коммерческой недвижимостью
# или каким-то иным видом помещения, где указать количество комнат нельзя. <br>
# Сделаем предположение, что так как столбцы studio и rooms взаимосвязаны, то если количество комнат равно нулю это может быть студия.
# Проверим, нет ли аномалий.

# %%
display(data.query('(rooms == 0) & (not studio)')['last_price'].count())
data.query('(rooms == 0) & (not studio)').head()

# %% [markdown]
# Найдено 59 объектов, в которых rooms = 0, предположим, что это студии и заменим тип недвижимости

# %%
# Если количество комнат равно нулю, то это студия.
data.loc[data['rooms'] == 0, 'studio'] = True
data['rooms'].isna().sum()

# %% [markdown]
# <span style="color:blue"> **Столбцы с картографическими данными**</span>

# %% [markdown]
# При первоначальной выгрузке датасета было очевидно, что с картографическими данными есть проблема - слишком много пропусков, возможно, что это ошибка или проблема в передаче/выгрузке данных. Также было отмечено, что количество пропусков в столбцах было практически одинаковым:
#
# |Название столбца| количество пропусков |
# | --- | --- |
# | airports_nearest |  5542 |
# | cityCenters_nearest  |   5519 |
# | ponds_around3000   |  5518 |
# | parks_around3000    | 5518 |
#
# Проверим наше предположение.

# %%
#Посмотрим на пропуски значений в Санкт-Петербурге и других населенных пунктах
print('Столбец`airports_nearest` Санкт-Петербург: {} из {}'.format(
    data.query('locality_name == "Санкт-Петербург"')['airports_nearest'].isna().sum(),
    data.query('locality_name == "Санкт-Петербург"')['last_price'].count()
))
print('Столбец`city_center_nearest` Санкт-Петербург: {} из {}'.format(
    data.query('locality_name == "Санкт-Петербург"')['city_center_nearest'].isna().sum(), 
    data.query('locality_name == "Санкт-Петербург"')['last_price'].count()
))
print('Столбец `city_center_nearest` для других НП: {} из {}'.format( 
    data.query('locality_name != "Санкт-Петербург"')['city_center_nearest'].isna().sum(), 
    data.query('locality_name != "Санкт-Петербург"')['airports_nearest'].isna().sum(), 
    data.query('locality_name != "Санкт-Петербург"')['last_price'].count()
))
print('Столбец `airports_nearest` для других НП: {} из {}'.format( 
    data.query('locality_name != "Санкт-Петербург"')['airports_nearest'].isna().sum(), 
    data.query('locality_name != "Санкт-Петербург"')['last_price'].count()
))
print('Всего пропусков в `city_center_nearest`: {:.2%}'.format( 
    data['city_center_nearest'].isna().sum() / len(data)
))
print('Всего пропусков в `airports_nearest`: {:.2%}'.format( 
    data['airports_nearest'].isna().sum() / len(data)
))

#Заполним пропуски нулями

data['city_center_nearest'] = data['city_center_nearest'].fillna(0)
#data['airports_nearest'] = data['airports_nearest'].fillna(0)

# %% [markdown]
# * Столбец`airports_nearest` Санкт-Петербург: 84 из 15651
# * Столбец`city_center_nearest` Санкт-Петербург: 60 из 15651
# * Столбец `city_center_nearest` для других НП: 5449 из 5448
# * Столбец `airports_nearest` для других НП: 5448 из 7962
# * Всего пропусков в `city_center_nearest`: 23.33%
# * Всего пропусков в `airports_nearest`: 23.43%
#
# Причина по которой могли появиться пропуски:
# возможно сервис карт ничего не находил, находясь в удаленных или малых населенных пунктах, в то время как в СПБ ближайший аэропорт находился сразу. Скорее всего, это и привело к пропускам в этих столбцах.

# %%
# Посчитаем значения в parks_around3000 с группировкой по пропускам parks_nearest
display(data[data['parks_nearest'].isna()].groupby(by='parks_around3000')['parks_around3000'].count())

display(data[data['parks_nearest'].isna()==False].groupby(by='parks_around3000')['parks_around3000'].count())
#Максимальное значение столбца parks_nearest
data['parks_nearest'].max()

# %%
data.plot(x='parks_nearest', y='parks_around3000', kind='scatter', grid=True, figsize=(15, 5))
plt.title("Корреляция столбцов parks")
plt.ylabel("around3000")
plt.xlabel("nearest")
plt.show()
print('Корреляция: {:.1%}'.format(data['parks_nearest'].corr(data['parks_around3000'])))

# %% [markdown]
# В 15535 строк столбец "parks_around3000" заполнен нулями, а "parks_nearest" не заполнено.
# Максимальное значение в parks_nearest 3190, возможно, свыше этого расстояния столбец не заполнялся.
# Заменять пропущенные 'ponds_nearest' и 'parks_nearest' медианой будет нелогично, как и любым другим конкретным.
# Единственное, что можно отметить, что с увеличением расстояния снижается уровень заполняемости столбцов.
# Пропуски решено оставить.

# %% [markdown]
# Аналогично проверим данные по водоемам.

# %%
# Посчитаем значения в ponds_around3000 с группировкой по пропускам ponds_nearest
display(data[data['ponds_nearest'].isna()].groupby(by='ponds_around3000')['ponds_around3000'].count())

display(data[data['ponds_nearest'].isna()==False].groupby(by='ponds_around3000')['ponds_around3000'].count())
#Максимальное значение столбца parks_nearest
data['ponds_nearest'].max()

# %% [markdown]
# Пропуски решено оставить.

# %%
data.plot(x='ponds_nearest', y='ponds_around3000', kind='scatter', grid=True, figsize=(15, 5))
plt.title("Корреляция столбцов ponds")
plt.ylabel("around3000")
plt.xlabel("nearest")
plt.show()
print('Корреляция: {:.1%}'.format(data['ponds_nearest'].corr(data['ponds_around3000'])))

# %%
data['airports_nearest'].describe()

# %%
data.query('airports_nearest < 1000')

# %% [markdown]
# Изучив пропуски данных столбцах, не было обнаружено никаких закономерностей,
# параметры никак не связаны с остальными, поэтому как-то вычислить их нельзя. Было решено оставить пропуски.

# %% [markdown]
# <span style="color:blue">**Столбец days_exposition**</span>

# %%
#Посмотрим на самую раннюю и позднюю даты
display(min(data['first_day_exposition']),max(data['first_day_exposition']))

# %%
#Отсортируем данные в first_day_exposition, отфильтровав пропуски в days_exposition
display(data[data['days_exposition'].isna()]['first_day_exposition'].sort_values())

#Построим гистрограмму
data[data['days_exposition'].isna()]['first_day_exposition'].hist(bins=50, figsize=(25,5))
#Проверим количество пропусков 
data['first_day_exposition'].isna().sum()

# %% [markdown]
# Даты объявлений с 2014 по 2019г, гистограма демонстрирует, что большинство объявлений с незавершенной датой приходятся на 2019, возможно, к моменту выгрузки данных они еще были активны. С данными все в порядке, никаких преобразований, кроме ранее сделанного форматирования даты не нужно.

# %%
#Предварительно заполним пропуски нулями.
data['days_exposition'] = data['days_exposition'].fillna(0)
data['days_exposition'].isna().sum()

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Лучше такую замену не делать, так как в данных уже могут быть значения равные 0, и получается мы не сможем отделить не проданные объекты от проданных, тут лучше оставить пропуски.
#
#
# </div>

# %% [markdown]
# <span style="color:red">**Замена типов данных**</span>

# %%
#Предварительно заполним пропуски нулями.
data['days_exposition'] = data['days_exposition'].fillna(0)
data['days_exposition'].isna().sum()

# %% [markdown]
# Требуется заменить некоторые значения float на int в тех случаях, где значения могут быть только целыми числами, и object на datetime в столбце, где указана дата публикации объявления.

# %%
data['floors_total'] = data['floors_total'].astype('int')
data['balcony'] = data['balcony'].astype('int')
#data['parks_around3000'] = data['parks_around3000'].astype('int')
#data['ponds_around3000'] = data['ponds_around3000'].astype('int')
data['days_exposition'] = data['days_exposition'].astype('int')
data['is_apartment'] = data['is_apartment'].astype('bool')

data.info()

# %%
#Подсчитаем оставшиеся пропускови и посмотрим на процентное соотношение
display(pd.DataFrame(round((data.isna().mean()*100),2).sort_values(ascending=False)\
                     ,columns=['NaNs, %']).style.format('{:.2f}').background_gradient('bwr'))
data.isna().sum().sort_values(ascending=False)

# %% [markdown]
# <span style="color:red">**Вывод по предварительной обработке данных**</span>

# %% [markdown]
# **Вывод**<br> <br>
# <u>*Получение общей информации*</u><br>
# - При получении первичной информации было отмечено, общее количество пропусков составило 19%. Пропуски в столбцах is_apartment и balcony могли возникнуть из-за того, что поле было не обязательным, и пользователи оставляли его пустым, однако полностью исключить техническую ошибку нельзя. <br>
# - Большая группа пропусков связана с данными, полученными из картографии: столбцы parks_nearest и ponds_nearest, airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000. Более того, процент пропусков в столбцах airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000 почти одинаковый, что может быть связано с общей проблемой при загрузке данных. <br>
# - В колонках ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name, distance_airport, distance_city_center, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition есть пропуски. <br>
# - На первый взгляд, аномалиями могут быть: 50 фото в объявлении, большая высота потолков, площадь кухни в 112 кв., и др. Необходимо проанализировать каждый столбец и проверить, какие значения являются аномалией и устранить их. Также, имеются проблемы с типом данных, логично поменять тип данных на "int" в "floors_total", "balcony", "parks_around3000", "ponds_around3000" поскольку количество этажей, дней и балконов, парков и водоёмов не может быть нецелочисленным значением. <br>
# - Требуется заменить некоторые значения float на int в тех случаях, где значения могут быть только целыми числами, и object на datetime в столбце, где указана дата публикации объявления. <br>
#
#
# <u>*Предварительная обработка данных: работа с пропусками и аномалиями*</u> <br> <br>
# В ходе предварительной обработки данных нами изучены и описаны следующие параметры:<br>
#  - **общая площадь;** <br>
# Аномальными выбросами выглядит общая площадь > 600м.
# Также было проверено,  что сумма жилой площади и площади кухни не превышает общую площадь и произведены замены.<br>
#  - **жилая площадь;**<br>
# По графику и коэффициенту корреляции Пирсона был сделан вывод, что существует линейная связь между показателями. Таким образом, данные столбца total_area были использованы для заполнения пропусков в living_area.<br>
#  - **площадь кухни;**<br>
# Пропуски в kitchen_area (10%) возможно связаны как с технической ошибкой, так и с квартирами-студиями или открытой планировкой.
# Была простроена сводная таблица с подсчетом медианы и количества значений
#  площади  кухни для студий и открытых планировок, как и предполагалось, ни в квартирах с открытыми планировками, ни в студиях площадь кухни не указана.<br>
# Пропуски в кухонной площади для открытых планировок и студий были заполнены нулям.
# Была найдена зависимость между общей площадью квартир и площадью кухни для заполнения и оставшиеся 2009 пропусков были заполнены с использованием данных  total_area<br>
#
#  - **количество комнат;** <br>
# В 194 объектах количество комнат было равно нулю, было сделано предположение, что так как столбцы studio и rooms взаимосвязаны, то если количество комнат равно нулю это может быть студия, в найденных объектах тип недвижимости был заменен тип недвижимости на студию. <br>
#  - **высота потолков;** <br>
# При анализе пропущенных и аномальных значений была найдена небольшая корреляция общей площади квартиры и высоты потолка и расстояния от центра и высоты потолка, однако, было решено, что ее недостаточно чтобы заполнять столбцы. Зависимости высоты потолка от этажа или этажности здания найдено не было. <br>
# Столбцы было решено заполнить медианным значением признака 2.65, отбросив сначала аномальные данные: высоту меньше 2м. и больше 5. При медианном значении в 2.65 в столбце отмечаются аномальные значения в 1 м. и 100 м., и 9084 пропуска <br>
#  - **этаж квартиры;**<br>
# Пропущенных и аномальных значений не найдено. <br>
#  - **тип этажа квартиры («первый», «последний», «другой»);**<br>
# Добавлен столбец 'floor_position' со значениями: не первый/не последний, первый, последний. <br>
#  - **общее количество этажей в доме;** <br>
# Пропуски в столбце были заменены нулями, при проверке на аномальные показатели было отмечено, что большое количество этажей в домах СПб выглядит нормальным, однако 60-этажное здание Кронштадта вызывало вопросы, возможно в таблице была опечатка. <br>
#  - **местонахождение квартиры;** <br>
# Удалены дубликаты, произведена категоризация по наслеленному пункту (город, село и др.)
#  - **картографические данные;** <br>
# При первоначальной выгрузке датасета было очевидно, что с картографическими данными есть проблема - слишком много пропусков, возможно, что это ошибка или проблема в передаче/выгрузке данных. Также было отмечено, что количество пропусков в столбцах было практически одинаковым.
# Причина по которой могли появиться пропуски: анализ данных показал, что в СПб практически все данные были заполнены, в то время как в других населенных пунктах был значительный процент пропусков, возможно сервис карт ничего не находил, находясь в удаленных или малых населенных пунктах, в то время как в СПБ ближайший аэропорт находился сразу. Скорее всего, это и привело к пропускам в этих столбцах.Изучив пропуски данных столбцах, не было обнаружено никаких закономерностей,
# параметры никак не связаны с остальными, поэтому как-то вычислить их нельзя.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хороший, красиво оформленный, промежуточный вывод, сразу понятно, что будет далее в предобработке.
#
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
# Цена одного квадратного метра
data['meter_price'] = data['last_price']/data['total_area']
data['meter_price'] = data['meter_price'].astype(int)
display(data['meter_price'])
display(data['meter_price'].mean())

# %% [markdown]
# Цена одного квадратного метра = 99349

# %%
# День недели публикации объявления
data['day_of_week_exposition']= data['first_day_exposition'].dt.weekday
data['month_exposition']=data['first_day_exposition'].dt.month
data['years_exposition']=data['first_day_exposition'].dt.year
data.head()

# %%
# Заменил цифры названиями дней недели
def weekday_of_exposition(row):
    weekday = row
    if weekday == 0:
        return 'понедельник'
    if weekday == 1:
        return 'вторник'
    if weekday == 2:
        return 'среда'
    if weekday == 3:
        return 'четверг'
    if weekday == 4:
        return 'пятница'
    if weekday == 5:
        return 'суббота'
    if weekday == 6:
        return 'воскресенье'
    return 'неизвестно'

data['weekday_of_exposition'] = data['day_of_week_exposition'].apply(weekday_of_exposition)
data.head()

# %%
# Этаж квартиры
data['floor_position'] = ['другой'] * len(data)
data.loc[data['floor'] == 1, 'floor_position'] = 'первый'
data.loc[data['floor'] == data['floors_total'], 'floor_position'] = 'последний'
data.head()

# %%
# Категоризация по населенному пункту
def split_by_type(dataset):
    df = pd.DataFrame(dataset, columns=['locality_name'])
    df['Type'] = df['locality_name'].apply(lambda x: x.split()[0] if isinstance(x, str) else [])
    grouped = df.groupby('Type')['locality_name'].apply(list)

    return grouped



data['locality_group'] = data[].apply(groupping_locality)

data.head(10)

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Тут синтаксическая ошибка.
#
#
# </div>

# %%
# Cоотношение жилой и общей площади, отношение площади кухни к общей
data['living_to_total'] = data['living_area'] / data['total_area']
data['kitchen_to_total'] = data['kitchen_area'] / data['total_area']

# Посмотрим на результат добавления столбцов
data.head()

# %%
# Расстояние до центра в километрах
data['city_center_km'] = (data['city_center_nearest'] / 1000).round(0)
data.head()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, корректно созданы дополнительные столбцы с необходимыми метриками.
#
# </div>

# %% [markdown]
# **Вывод**<br>
#
# В таблицу добавлены новые столбцы со следующими параметрами:<br>
#
# 1. цена одного квадратного метра;<br>
# 1. день недели публикации объявления;<br>
# 1. месяц публикации объявления;<br>
# 1. год публикации объявления;<br>
# 1. тип этажа квартиры (значения — «‎первый», «последний», «другой»);<br>
# 1. расстояние до центра города в километрах.<br>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# <span style="color:#ff0cb6">**Общая площадь**</span>

# %%
display(data['total_area'].describe())
data['total_area'].hist(bins=100, range = (0, 250), figsize=(15, 5))
plt.title("Распределение общей площади")
plt.ylabel("Количество")
plt.xlabel("Общая площадь")
plt.show()

# %% [markdown]
# Двугорбая гистограмма общей площади имеет вид распределения Пуассона, что возможно, обусловлено тем, что в одной выборке данных, присутствуюет несколько выборк (в нашем случае, несколько типов квартир) <br>
# Квартиры с очень маленькой площадью мало, по сравнению с другими.<br>
# Начиная с 30 кв.м. график стремится вверх и плотно держится до начала 60 кв.м., характерный диапазон наиболее типовых квартир - однокомнатных и студий. <br>
# Далее график убывает - квартир со слишком большой площадью тоже немного, после 200 кв.м. есть незначительные выбросы.<br>

# %% [markdown]
# <span style="color:#ff0cb6">**Жилая площадь**</span>

# %%
display(data['living_area'].describe())
data['living_area'].hist(bins=70, range=(0,200))
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Верно, хороший и подробный вывод 😃
#
# </div>

# %% [markdown]
# В распределени Пуассона видны два пика, первый пик, похоже, дают однокомнатные квартиры и студии, <br>
# как  очень распространненый тип жилья. <br>
# Второй пик соответсвует жилой площади 30 кв.м.<br>
# Столбчатость говорит о наиболее частых типах.

# %% [markdown]
# <span style="color:#ff0cb6">**Кухня**</span>

# %%
data['kitchen_area'].describe()

# %%
data['kitchen_area'].hist(bins=50,range=(0,50))
plt.show()

# %% [markdown]
# Гистограмма имеет пик примерно в 9 квадратных метров, с длинным хвостом вправо, <br>
# график резко проседает в районе 15 м., <br>
# что очевидно - кухни большего размера, скорее, редкость.<br>
# Можно также заметить подобие столбчатой структуры, отражающей наиболее типовые размеры кухонь. <br>

# %% [markdown]
# <span style="color:#ff0cb6">**Цена**</span>

# %%
data['last_price'].describe()

# %%
data['last_price'].describe().hist(bins = 100, range = (100000, 40000000))

plt.title('Данные с 2014 по 2019 г.')
plt.xlabel("Цена на момент снятия с публикации")
plt.ylabel("Количество квартир")
plt.show()

# %% [markdown]
# На гистограмме цены мы видим кривую нормального распределения с длинным хвостом вправо.<br>
# Больше 30 000 000 это, по всей видимости, выбросы.

# %%
data.boxplot('last_price').set_title('Цена квартиры')
plt.ylim(700000,70000000)
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Стоимость квартиры чаще всего находится в промежутке от 2млн.рублей до 8млн.рублей.

# %% [markdown]
# <span style="color:#ff0cb6">**Количество комнат**</span>

# %%
data['rooms'].describe()

# %%
data.boxplot('rooms').set_title('Количество комнат в квартире')
plt.ylabel('Количество комнат')
plt.show()
data['rooms'].hist(bins = 11, range = (0, 10))
plt.title('Количество комнат в квартире')
plt.ylabel('Количество квартир')
plt.xlabel('Количество комнат')
plt.show()

# %% [markdown]
# Гистограмма, отражающая количество комнат, имеет вид диаграммы Пуассона. <br>
# По ней видно, что больше всего на рынке однокомнатных и двухкомнатных квартир - практически одинаковое количество.<br>
# На третьем месте трехкомнатные, но отставание тоже невелико.<br>
# Резкая просадка графиков по квартирам 4 или более комнат.

# %% [markdown]
# <span style="color:#ff0cb6">**Высота потолка**</span>

# %%
data['ceiling_height'].describe()

# %%
data['ceiling_height'].hist(bins=10,range=(2,4))
plt.show()

# %% [markdown]
# Гистограмма высоты потолков имеет пик около 2.5 - 2.7 метра.

# %% [markdown]
# <span style="color:#ff0cb6">**Этаж**</span>

# %%
data['floor'].describe()

# %%
data['floor'].hist(bins=30,range=(0,30))
plt.show()

# %% [markdown]
# Этаж принимает вид распределения Пуассона с пиком на 4 этаже.
# Много продаж на первом этаже, чем выше этаж тем меньше предложений квартир.

# %%
data['floor_position'].hist()

# %% [markdown]
# На следующей диаграмме видно, что квартиры на первом этаже продаются чуть реже чем на последнем, <br>
# возможно это связано с тем что на первом этаже жилых домов часто коммерческая недвижимость. <br>
# Квартир категории "другой" ожидаемо значительно больше.

# %% [markdown]
# <span style="color:#ff0cb6">**Количество этажей**</span>

# %%
data['floors_total'].describe()

# %%
data['floors_total'].hist(bins=5,range=(0,40));
plt.show()
data['floors_total'].hist(bins=len(data['floors_total'].unique()))
plt.show()

# %% [markdown]
# Этажность здания описывается кривой распределения Пуассона, <br>
# напоминающей ступеньки, что говорит о распространённой этажности зданий.<br>
# Что и продемонстрировано на 2 графике:<br>
# - 5-этаж.
# - 9-этаж.
# - 12-этаж. и 16-этаж.
# - 25-этаж.

# %% [markdown]
# <span style="color:#ff0cb6">**Расстояние до центра в км.**</span>

# %%
data['city_center_km'].describe()

# %%
data['city_center_km'].hist(bins=50)
plt.show()

# %% [markdown]
# Большинство квартир находятся в диапазоне от 5 до 20 км от центра города.

# %% [markdown]
# <span style="color:#ff0cb6">**Расстояние до аэропорта**</span>

# %%
data['airports_nearest'].describe()

# %%
data['airports_nearest'].hist(bins=30)
plt.show()

# %% [markdown]
# Нормальное распредедение с длинным выделяющимся пиком примерно в 25-26 км от аэропорта

# %% [markdown]
# <span style="color:#ff0cb6">**Ближайший парк**</span>

# %%
data['parks_nearest'].describe()

# %%
data['parks_nearest'].hist(bins=20)
plt.show()

# %% [markdown]
# Из доли обьявлений с заполненным параметром у большинства парк находится в радиусе километра.

# %% [markdown]
# <span style="color:#ff0cb6">**Изучим, как быстро продавались квартиры.**</span>

# %%
data['days_exposition'].describe()

# %%
data['days_exposition'].hist(bins = 100, range = (1, 1580))

plt.title('Количество дней в продаже')
plt.xlabel("Длительность размещения")
plt.ylabel("Количество квартир")
plt.show()
data.boxplot('days_exposition')
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, верно интерпретированы данные из графика и .describe() 😃
#
# </div>

# %% [markdown]
# Распределение продаж по длительности описывается диаграммой распределения Пуассона.<br>
# Большая часть квартир продаётся в течение первых 4 месяцев публикации, далее количество объявлений снижается. <br>
# Медианное значение 75 дней. Половина всех продаж лежит в рамках от 45 до 232 дней.<br>
# На графике "boxplot" очевиден длинный верхний "ус", это означает что некоторые квартиры продавались намного дольше. <br>
# Самая быстрая продажа 1 день, медленные продажи - дольше 500 дней.<br>
# Для категоризации длительности продажи квартир можно использовать следующие условия:<br>
#
# - Если значение столбца "days_exposition" больше 180 дней, то продажа считается долгой.<br>
# - Если значение столбца "days_exposition" меньше 180 дней, то продажа считается быстрой.<br>

# %%
def categorize_sale_duration(dataframe):
    dataframe['sale_duration_category'] = pd.cut(dataframe['days_exposition'], bins=[
        0, 180, float('inf')], labels=['быстрая', 'долгая'])
    return dataframe

categorize_sale_duration(data)
data['sale_duration_category'].value_counts() 
#data.head()

# %%
data['sale_duration_category'].value_counts().plot(kind='bar')
plt.xlabel('Категория длительности продажи')
plt.ylabel('Количество квартир')
plt.title('Длительность продажи квартир')
plt.show()

# %%
plt.scatter(data['total_area'], data['last_price'], c=data['sale_duration_category'].astype('category').cat.codes)
plt.show()

# %% [markdown]
# Из графика можно сделать вывод о том, что категория длительности продажи связана с общей площадью и ценой. <br>
# Например, мы видим, что большинство точек сгруппировано в нижней части графика (маленькая общая площадь и низкая цена),<br>
# то можно предположить, что в этой категории длительности продажи цены и площади квартир могут быть ниже,<br>
# чем в категории сгруппированных точек в верхней части графика (большая общая площадь и высокая цена).
# А также то, что большинство продаж происходит в категории "длительность продажи до 180 дней", <br>
# позволяет предположить, что в этой категории цены и площади квартир могут быть ниже, чем в категории <br>
# "длительность продажи более 180 дней".<br>

# %%
#Рассмотрим конец и начало диаграммы подробнее
data['days_exposition'].hist(bins = 10, range = (1, 10))
plt.title('Количество дней в продаже')
plt.xlabel("Длительность размещения")
plt.ylabel("Количество квартир")
plt.show()
# Район 40-60 дней
data['days_exposition'].hist(bins = 150, figsize = (15,3), range=(40,60))
plt.title('Количество дней в продаже')
plt.xlabel("Длительность размещения")
plt.ylabel("Количество квартир")
plt.show()
data['days_exposition'].hist(bins = 50, range = (800, 1580))
plt.title('Количество дней в продаже')
plt.xlabel("Длительность размещения")
plt.ylabel("Количество квартир")
plt.show()
data['days_exposition'].value_counts().sort_values(ascending=False).head(5)

# %% [markdown]
# На первой гистограмме видно, что основные продажи квартир начинаются через 3 дня после публикации. <br>
# Пики 45 и 60 дней связаны с истечением срока размщения объявления.<br>
# Вторая гистограмма показывает, что при длительном времени публикации, падение происходит практически линейно.<br>

# %%
print("Количество квартир, которые продавались больше года:", data[data['days_exposition'] >= 365].count()[0])
print("Количество квартир, которые продавались больше 2 лет:", data[data['days_exposition'] >= 730].count()[0])
print("Количество квартир, которые продавались больше 3 лет:", data[data['days_exposition'] >= 1095].count()[0])
print("Количество квартир, которые продавались больше 4 лет:", data[data['days_exposition'] >= 1460].count()[0])

# %%
data['weekday_of_exposition'].hist(bins=7)
plt.title('День недели размещения')
plt.show()
data['month_exposition'].hist(bins=12)
plt.title('Месяц размещения')
plt.show()

# %% [markdown]
# На гистограмме видим, что в выходные частотность реже, а в будние дни есть незначительные колебания.<br>
# Меньше всего объявлений в мае и в январе. Летом-осенью объявлений меньше, чем зимой-весной.

# %%
#Посмотрим на сводную таблицу
data.pivot_table(index=['month_exposition'], columns=['weekday_of_exposition'], values='last_price', aggfunc=['count']).plot(kind='bar', figsize=(9,9))
plt.show()

# %% [markdown]
# Чаще всего:<br>
#
# - Февраль/Четверг
# - Октябрь/Пятница
# - Март/Вторник

# %% [markdown]
#  <span style="color:#ff0cb6">**Изучим, какие факторы больше всего влияют на общую (полную) стоимость объекта.**</span>

# %%
df = data[['last_price', 'total_area', 'rooms', 'floor', 'first_day_exposition']]
pd.plotting.scatter_matrix(df)
plt.show()

# %% [markdown]
#  <span style="color:##777fff">**total_area**</span>

# %%
plt.scatter(data['total_area'], data['last_price'])
plt.xlabel('Total Area')
plt.ylabel('Price')
plt.title('Price vs Total Area')
plt.show()

#И рассмотрим поближе
data.pivot_table(index='total_area', 
                 values='last_price').reset_index().plot(x='total_area',
                                                         y='last_price',
                                                         xlim=(0,150),
                                                         ylim=(0,50000000),
                                                         kind='scatter',
                                                         alpha=0.3,
                                                         grid= True,
                                                         title='total_area',
                                                         figsize=(8,6));

# %%
print('Корреляция составляет:',"{:.2%}".format(data['total_area'].corr(data['last_price'])))

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Полный вывод, правильно посчитана и интерпретирована корреляция.
#
# </div>

# %% [markdown]
# Из графика видно, что цена имеет положительную корреляцию (65%) с общей площадью квартиры. Чем больше площадь, тем выше цена.

# %% [markdown]
#  <span style="color:##777fff">**living_area**</span>

# %%
plt.scatter(data['living_area'], data['last_price'])
plt.xlabel('Living Area')
plt.ylabel('Price')
plt.title('Price vs Living Area')
plt.show()

# более подробно
data.pivot_table(index='living_area',
                 values='last_price').reset_index().plot(x='living_area',
                                                         y='last_price',
                                                         xlim= (0,150),
                                                         ylim=(0,50000000),
                                                         kind='scatter',
                                                         alpha=0.3,
                                                         title='living_area',
                                                         figsize=(8,6),
                                                         grid=True);

# %%
print('Корреляция составляет:',"{:.2%}".format(data['living_area'].corr(data['last_price'])))

# %% [markdown]
# Из графика видно, что цена также имеет, хотя и меньшую (59%), но положительную корреляцию с жилой площадью.<br>
# Чем больше жилая площадь, тем выше цена.

# %% [markdown]
#  <span style="color:##777fff">**rooms**</span>

# %%
display(data.pivot_table(index='rooms', values='last_price', aggfunc=['count','min','mean','median','max']))

# %%
plt.scatter(data['rooms'], data['last_price'])
plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.title('Price vs Number of Rooms')
plt.show()

print('Корреляция составляет:',"{:.2%}".format(data['rooms'].corr(data['last_price'])))

# %% [markdown]
# Из графика видно, что цена имеет положительную корреляцию с количеством комнат (36%). Чем больше комнат, тем выше цена.

# %% [markdown]
#  <span style="color:##777fff">**kitchen_area**</span>

# %%
plt.scatter(data['kitchen_area'], data['last_price'])
plt.xlabel('Kitchen Area')
plt.ylabel('Price')
plt.title('Price vs Kitchen Area')
plt.show()

data.pivot_table(index='kitchen_area',
                 values='last_price').reset_index().plot(x='kitchen_area',
                                                         y='last_price',
                                                         xlim=(0,50),
                                                         ylim=(0,50000000),
                                                         kind='scatter',
                                                         alpha=0.3,
                                                         title='kitchen_area',
                                                         figsize=(8,6),
                                                         grid=True);

# %%
print('Корреляция составляет:',"{:.2%}".format(data['kitchen_area'].corr(data['last_price'])))

# %% [markdown]
# Из графика видно, что цена имеет слабую положительную корреляцию с площадью кухни (51%). <br>
# Однако эта зависимость не так явно выражена, как в случае с общей и жилой площадью.

# %% [markdown]
#  <span style="color:##777fff">**floor**</span>

# %%
data.plot(x='floor_position', y='last_price', ylim=(0, 100000000), kind='scatter', alpha=0.3)
plt.show()
data.pivot_table(index ='floor_position', values='last_price')

# %% [markdown]
# Наблюдаем зависимость - квартиры на первом этаже дешевле всего, квартиры на последнем этаже более ценны. <br>
# Наиболее высокую цену имеют квартиры на "средних" этажах.

# %% [markdown]
# <span style="color:##777fff">**city_center_km**</span>

# %%
print('Корреляция составляет:', data['city_center_nearest'].corr(data['last_price']))
(data.pivot_table(index='city_center_nearest',values='last_price',aggfunc='median')
 .plot(kind='line', style='o', grid=True, figsize=(10, 6))
)
plt.title('Зависимость удаленность от центра/цена')
plt.xlabel("Удалённость от центра")
plt.ylabel("Цена")
plt.show()

# %% [markdown]
# На графике и по значению корреляции видна обратная зависимость (-0.2) - с ростом удалённости от центра средняяя стоимость квартиры падает.<br> В центре города присутствуют значительно более дорогие предложения.

# %% [markdown]
# <span style="color:##777fff">**years_exposition/month_exposition/day_of_week_exposition**</span>

# %%
(data
 .pivot_table(index='years_exposition', values='last_price', aggfunc='mean')
 .plot(kind='bar', grid=True, figsize=(10, 6)))
plt.show()

(data
 .pivot_table(index='month_exposition', values='last_price', aggfunc='mean')
 .plot(kind='bar', grid=True, figsize=(10, 6)))
plt.show()

(data
 .pivot_table(index='day_of_week_exposition', values='last_price', aggfunc='mean')
 .plot(kind='bar', grid=True, figsize=(10, 6)))
plt.show()

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Да, выводы верные, исходя из данного графика. Рекомендую дополнительно рассмотреть динамику цены м2 по годам. И сделать дополнительные выводы.
#
# </div>

# %%
print('Корреляция составляет:', data['years_exposition'].corr(data['last_price']))
print('Корреляция составляет:', data['month_exposition'].corr(data['last_price']))
print('Корреляция составляет:', data['day_of_week_exposition'].corr(data['last_price']))

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Считать корреляцию для категориальных данных не корректно, так как корреляция применима только к линейным зависимостям, а зависимость от категории этажа, дня недели, месяца или года не линейна, чаще всего там есть сезонность. Тут у тебя построены столбчатые диаграммы по средним.
#
#
# </div>

# %% [markdown]
# Зависимости не обнаружено.<br>
# Наблюдается только значительное снижение цен на квартиры после 2014 года - почти 50%,<br>
# к 2019 году намечается незначительный подъём.<br>
# Можно предположить, что это связано со снижением покупательской способности.

# %% [markdown]
#  <span style="color:#ff0cb6">**Изучим 10 населённых пунктах с наибольшим числом объявлений**</span>

# %%
# Сводная таблицу цен квадратного метра по населенным пунктам
prices = data.pivot_table(index='locality_name', values='meter_price', aggfunc=['count', 'mean'])

# Переименуем столбцы
prices.columns = ['count', 'mean']

# Выводим топ 10 по количеству объявлений
prices.sort_values(by='count', ascending=False).head(10)

# %%
top_price = [
    'Санкт-Петербург', 'посёлок Мурино', 'посёлок Шушары', 'Всеволожск', 
    'Пушкин', 'Колпино', 'посёлок Парголово', 'Гатчина', 'деревня Кудрово', 'Выборг']

# %%
# Узнаем среднюю цену квадратного метра в топовых населённых пунктах
(prices
.query('locality_name in @top_price')
.groupby('locality_name')['mean'].mean().sort_values(ascending=False)
)

# %% [markdown]
# Самые дорогие квартиры в самом Санкт-Петербурге, а также в городе Пушкин. Самые дешевые квартиры из топа - в Выборге.

# %% [markdown]
# Оценим наиболее дорогие и дешёвые регионы без привязки к количеству объявлений:

# %%
# Весь датасет, отсортированный по средней стоимости м2
data_price_sorted = (data                  
                    .pivot_table(index='locality_name',
                                    values='meter_price',
                                    aggfunc='mean')
                      .sort_values('meter_price', ascending=False)
                    )
# Самые дорогие регионы
display(data_price_sorted.head(5))
data_price_sorted.tail(5)

# %%
top_price = (data.pivot_table( values=['meter_price','last_price'],
               index='locality_name',  
               aggfunc=['count','mean','max','min'])
 .set_axis(['number', '2', '3', 'meter_mean_price', 'max_price', '6', 'min_price', '8'], axis=1, inplace=False)

 .sort_values(by = 'number', ascending=False)
 .head(10)
 .loc[:, ['number','meter_mean_price', 'max_price','min_price']]
 .sort_values(by = 'number', ascending=False)
 .round({'meter_mean_price':2}) )
top_price

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Построй, пожалуйста, столбчатую диаграмму или ящики с усами стоимости квадратного метра по топ 10 населенным пунктам.
#
#
# </div>

# %% [markdown]
#  <span style="color:#ff0cb6">**Изучим квартиры в Санкт-Петербурге**</span>

# %%
# Выделим квартиры в Санкт-Петербурге:
data_spb = data.query('locality_name == "Санкт-Петербург" ')



# Построим гистограмму, чтобы определить границу центра
((data_spb
  .pivot_table(index='city_center_km',values='meter_price',aggfunc='mean')
  .plot(kind='bar', grid=True, figsize=(10, 6))))
plt.show()
((data_spb
  .pivot_table(index='city_center_km',values='meter_price',aggfunc='mean')
  .plot(kind='line', style='o-', grid=True, figsize=(10, 6))))
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Супер, корректно выделены квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислена средняя цена каждого километра.
#
# </div>

# %%
data_spb = data_spb.query('city_center_km <= 8')
data_spb = data_spb.reset_index(drop=True)
data_spb

# %%
data_spb['total_area'].describe()

# %%
data['total_area'].describe()

# %%
plt.figure(figsize=(10, 8))
plt.boxplot(data_spb['total_area'])
plt.title('Центр Спб')
plt.xlabel('total_area')
plt.ylabel('Цена')
plt.show()

plt.figure(figsize=(10, 8))
plt.boxplot(data['total_area'])
plt.title('Data')
plt.xlabel('total_area')
plt.ylabel('Цена')
plt.show()

# %%
data_spb['living_area'].describe()

# %%
data['living_area'].describe()

# %%
plt.figure(figsize=(10, 8))
plt.boxplot(data_spb['living_area'])
plt.title('Центр Спб')
plt.xlabel('living_area')
plt.ylabel('Цена')
plt.show()

plt.figure(figsize=(10, 8))
plt.boxplot(data['living_area'])
plt.title('Data')
plt.xlabel('living_area')
plt.ylabel('Цена')
plt.show()

# %%
data_spb['last_price'].describe()

# %%
data['last_price'].describe()

# %%
plt.figure(figsize=(10, 8))
plt.boxplot(data_spb['last_price'])
plt.title('Центр Спб')
plt.xlabel('last_price')
plt.ylabel('Цена')
plt.show()

plt.figure(figsize=(10, 8))
plt.boxplot(data['last_price'])
plt.title('Data')
plt.xlabel('last_price')
plt.ylabel('Цена')
plt.show()

# %%
data['ceiling_height'].describe()

# %%
data_spb['ceiling_height'].describe()

# %%
plt.figure(figsize=(10, 8))
plt.boxplot(data_spb['ceiling_height'])
plt.title('Центр Спб')
plt.xlabel('rceiling_height')
plt.ylabel('m')
plt.show()

plt.figure(figsize=(10, 8))
plt.boxplot(data['ceiling_height'])
plt.title('Data')
plt.xlabel('ceiling_height')
plt.ylabel('m')
plt.show()

# %%
data_spb['rooms'].describe()

# %%
data['rooms'].describe()

# %%
plt.figure(figsize=(10, 8))
plt.boxplot(data_spb['rooms'])
plt.title('Центр Спб')
plt.xlabel('rooms')
plt.ylabel('Кол-во')
plt.show()

plt.figure(figsize=(10, 8))
plt.boxplot(data['rooms'])
plt.title('Data')
plt.xlabel('rooms')
plt.ylabel('Кол-во')
plt.show()

# %%
center_factors = ['rooms','total_area','living_area','kitchen_area','floor', 'city_center_nearest', 'years_exposition']
# Создаем пустой DataFrame для сохранения результатов корреляции
correlation_results = pd.DataFrame(columns=['Factor', 'Correlation'])

# Перебираем столбцы center_factors
for factor in center_factors:
    # Создаем диаграмму рассеяния
    plt.figure(figsize=(8, 6))
    plt.scatter(data_spb[factor], data_spb['last_price'])
    plt.title(f'Correlation between {factor} and last_price')
    plt.xlabel(factor)
    plt.ylabel('last_price')
    plt.show()
    
    # Создаем pivot таблицу для вычисления корреляции
    pivot_table = data_spb.pivot_table(index=factor, values='last_price', aggfunc='mean')
    
    # Вычисляем корреляцию между столбцом factor и last_price
    correlation = data_spb[factor].corr(data_spb['last_price'])
    
    # Добавляем результаты корреляции в DataFrame
    correlation_results = correlation_results.append({'Factor': factor, 'Correlation': correlation}, ignore_index=True)

# Выводим результаты корреляции
correlation_results

# %%
enter_factors = ['rooms','total_area','living_area','kitchen_area','floor', 'city_center_nearest', 'years_exposition']
# Создаем пустой DataFrame для сохранения результатов корреляции
correlation_results = pd.DataFrame(columns=['Factor', 'Correlation'])

# Перебираем столбцы center_factors
for factor in center_factors:
    # Создаем диаграмму рассеяния
    plt.figure(figsize=(8, 6))
    plt.scatter(data[factor], data['last_price'])
    plt.title(f'Correlation between {factor} and last_price')
    plt.xlabel(factor)
    plt.ylabel('last_price')
    plt.show()
    
    # Создаем pivot таблицу для вычисления корреляции
    pivot_table = data.pivot_table(index=factor, values='last_price', aggfunc='mean')
    
    # Вычисляем корреляцию между столбцом factor и last_price
    correlation = data[factor].corr(data['last_price'])
    
    # Добавляем результаты корреляции в DataFrame
    correlation_results = correlation_results.append({'Factor': factor, 'Correlation': correlation}, ignore_index=True)

# Выводим результаты корреляции
correlation_results

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Красивое построение и выводы правильные, молодец 😃
#
# </div>

# %% [markdown]
# В ходе анализа диаграмм было выявлено, что в центре: <br>
# - выше высота потолков (2.79 СПБ/2.65 Data)<br>
# - дороже стоимость (8,95 СПБ/4,65 Data)<br>
# площадь квартир в центре Санкт-Петербурга существенно больше, чем в остальных районах<br>
# - больше площадь (76 СПБ/52 Data)<br>
# площадь квартир в центре Санкт-Петербурга существенно больше, чем в остальных районах<br>
# - количеству комнат (3 СПБ/2 Data)<br>
# у квартир в центре Санкт-Петербурга в среднем на одну комнату больше, чем в остальных районах<br>
#
# *в скобках медиана*<br>
#
#
# |Factor| Correlation СПБ |Correlation Data |
# | --- | --- | ---|
# | rooms |  0,34 | 0,36 |
# | total_area  |  0,63 | 0,65 |
# | living_area   |  0,56 | 0,58 |
# | kitchen_area    | 0,50 | 0,51 |
# | floor |  0,1 | 0,02 |
# | city_center_nearest  |   - 0,07 |- 0,2  |
# | years_exposition   | -0,46 |-,042 |
#
# Зависимость цены от количества комнат примерно одинаковая.<br>
# Соотношения в ценах по категориям этажа тоже схожи.<br>
# Стоимость снижается при удалении от центра.<br>
# Дата размещения не влияет на стоимость.<br>
# Немного больше коррелация в зависимости от этажа.<br>
# Ожидаемо уменьшилась корреляция по удаленности от центра, стоимость квартир, расположенных в радиусе 8 км от центра,
# наименее подвержена воздействию внешних факторов.

# %% [markdown]
# Для построения окончательного вывода еще раз посмотрим данные

# %%
corrs = ['total_area','rooms','city_center_nearest', 'kitchen_area', 'living_area', 'floor','day_of_week_exposition','month_exposition','years_exposition']

for column in corrs:
    print(column, round(data[column].corr(data['last_price']),2))

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# <u>*Получение общей информации*</u><br>
# - При получении первичной информации было отмечено, общее количество пропусков составило 19%. Пропуски в столбцах is_apartment и balcony могли возникнуть из-за того, что поле было не обязательным, и пользователи оставляли его пустым, однако полностью исключить техническую ошибку нельзя. <br>
# - Большая группа пропусков связана с данными, полученными из картографии: столбцы parks_nearest и ponds_nearest, airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000. Более того, процент пропусков в столбцах airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000 почти одинаковый, что может быть связано с общей проблемой при загрузке данных. <br>
# - В колонках ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name, distance_airport, distance_city_center, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition есть пропуски. <br>
# - На первый взгляд, аномалиями могут быть: 50 фото в объявлении, большая высота потолков, площадь кухни в 112 кв., и др. Необходимо проанализировать каждый столбец и проверить, какие значения являются аномалией и устранить их. Также, имеются проблемы с типом данных, логично поменять тип данных на "int" в "floors_total", "balcony", "parks_around3000", "ponds_around3000" поскольку количество этажей, дней и балконов, парков и водоёмов не может быть нецелочисленным значением. <br>
# - Требуется заменить некоторые значения float на int в тех случаях, где значения могут быть только целыми числами, и object на datetime в столбце, где указана дата публикации объявления. <br>
#
#
# <u>*Предварительная обработка данных: работа с пропусками и аномалиями*</u> <br> <br>
# В ходе предварительной обработки данных нами изучены и описаны следующие параметры:<br>
#  - **общая площадь;** <br>
# Аномальными выбросами выглядит общая площадь > 600м.
# Также было проверено,  что сумма жилой площади и площади кухни не превышает общую площадь и произведены замены.<br>
#  - **жилая площадь;**<br>
# По графику и коэффициенту корреляции Пирсона был сделан вывод, что существует линейная связь между показателями. Таким образом, данные столбца total_area были использованы для заполнения пропусков в living_area.<br>
#  - **площадь кухни;**<br>
# Пропуски в kitchen_area (10%) возможно связаны как с технической ошибкой, так и с квартирами-студиями или открытой планировкой.
# Была простроена сводная таблица с подсчетом медианы и количества значений
#  площади  кухни для студий и открытых планировок, как и предполагалось, ни в квартирах с открытыми планировками, ни в студиях площадь кухни не указана.<br>
# Пропуски в кухонной площади для открытых планировок и студий были заполнены нулям.
# Была найдена зависимость между общей площадью квартир и площадью кухни для заполнения и оставшиеся 2009 пропусков были заполнены с использованием данных  total_area<br>
#
#  - **количество комнат;** <br>
# В 194 объектах количество комнат было равно нулю, было сделано предположение, что так как столбцы studio и rooms взаимосвязаны, то если количество комнат равно нулю это может быть студия, в найденных объектах тип недвижимости был заменен тип недвижимости на студию. <br>
#  - **высота потолков;** <br>
# При анализе пропущенных и аномальных значений была найдена небольшая корреляция общей площади квартиры и высоты потолка и расстояния от центра и высоты потолка, однако, было решено, что ее недостаточно чтобы заполнять столбцы. Зависимости высоты потолка от этажа или этажности здания найдено не было. <br>
# Столбцы было решено заполнить медианным значением признака 2.65, отбросив сначала аномальные данные: высоту меньше 2м. и больше 5. При медианном значении в 2.65 в столбце отмечаются аномальные значения в 1 м. и 100 м., и 9084 пропуска <br>
#  - **этаж квартиры;**<br>
# Пропущенных и аномальных значений не найдено. <br>
#  - **тип этажа квартиры («первый», «последний», «другой»);**<br>
# Добавлен столбец 'floor_position' со значениями: не первый/не последний, первый, последний. <br>
#  - **общее количество этажей в доме;** <br>
# Пропуски в столбце были заменены нулями, при проверке на аномальные показатели было отмечено, что большое количество этажей в домах СПб выглядит нормальным, однако 60-этажное здание Кронштадта вызывало вопросы, возможно в таблице была опечатка. <br>
#  - **местонахождение квартиры;** <br>
# Удалены дубликаты, произведена категоризация по наслеленному пункту (город, село и др.)
#  - **картографические данные;** <br>
# При первоначальной выгрузке датасета было очевидно, что с картографическими данными есть проблема - слишком много пропусков, возможно, что это ошибка или проблема в передаче/выгрузке данных. Также было отмечено, что количество пропусков в столбцах было практически одинаковым.
# Причина по которой могли появиться пропуски: анализ данных показал, что в СПб практически все данные были заполнены, в то время как в других населенных пунктах был значительный процент пропусков, возможно сервис карт ничего не находил, находясь в удаленных или малых населенных пунктах, в то время как в СПБ ближайший аэропорт находился сразу. Скорее всего, это и привело к пропускам в этих столбцах.Изучив пропуски данных столбцах, не было обнаружено никаких закономерностей,
# параметры никак не связаны с остальными, поэтому как-то вычислить их нельзя.
#
#
# В таблицу добавлены новые столбцы со следующими параметрами:<br>
#
# 1. цена одного квадратного метра;<br>
# 1. день недели публикации объявления;<br>
# 1. месяц публикации объявления;<br>
# 1. год публикации объявления;<br>
# 1. тип этажа квартиры (значения — «первый», «последний», «другой»);<br>
# 1. расстояние до центра города в километрах.<br>
#
#
# **Исследовательский анализ данных**<br>
#
# - Обычно продажа квартиры занимает около 3-6 месяцев. Продажи, которые занимают менее 3 месяцев, можно считать быстрыми, а продажи, которые занимают более 6 месяцев, можно считать необычно долгими.<br>
# > количество быстраых продаж  (меньще 180 дней) --- 13959<br>
# дколичество долгих продаж  (больше 180 дней) ---    6482<br>
# Количество квартир, которые продавались больше года: 3052<br>
# Количество квартир, которые продавались больше 2 лет: 748<br>
# Количество квартир, которые продавались больше 3 лет: 168<br>
# Количество квартир, которые продавались больше 4 лет: 11<br>
#
#
# - Цена квартиры имеет положительную корреляцию с общей площадью, жилой площадью, количеством комнат и площадью кухни. Чем больше эти параметры, тем выше цена.<br>
#
# >**total_area 0.65**<br>
# **rooms 0.36**<br>
# **kitchen_area 0.51**<br>
# **living_area 0.59**<br>
#
# - Цена квартиры имеет отрицательную корреляцию с расстоянием от центра. Чем больше расстояние, тем ниже цена.<br>
#
# >**city_center_nearest -0.21**<br>
#
# - Квартиры на первом этаже имеют более низкую цену, чем квартиры на других этажах.<br>
#
#
# |floor_position| |
# | --- | --- |
# | другой |  7.674 |
# | первый |   4.823 |
# | последний   |  6.327 |
#
# - Распределение объявлений по дням недели, месяцам и годам неоднородно, в целом цена не показывает значительной зависимости от дня недели, месяца или года размещения объявления.<br>
#
# >**day_of_week_exposition 0.0**<br>
# **month_exposition 0.0**<br>
# **years_exposition -0.04**<br>
#
# - Средняя цена одного квадратного метра различается в разных населенных пунктах. Населенный пункт с самой высокой стоимостью квадратного метра - Санкт-Петербург (114817 p.), населенный пункт с самой низкой стоимостью квадратного метра - Выборг(58141 p.).<br>
# - В ходе анализа диаграмм было выявлено, что в центре: <br>
# 1. выше высота потолков (2.79 СПБ/2.65 Data)<br>
# 1. дороже стоимость (8,95 СПБ/4,65 Data)<br>
#  *площадь квартир в центре Санкт-Петербурга существенно больше, чем в остальных районах*<br>
# 1. больше площадь (76 СПБ/52 Data)<br>
#  *площадь квартир в центре Санкт-Петербурга существенно больше, чем в остальных районах*<br>
# 1. больше оличество комнат (3 СПБ/2 Data)<br>
#  *у квартир в центре Санкт-Петербурга в среднем на одну комнату больше, чем в остальных районах*<br>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Спасибо, очень хороший и подробный общий вывод, которые содержит все промежуточные результаты, добавлю несколько общих рекомендаций)
#
# В общем выводе хочется тезисно видеть все промежуточные выводы с цифрами. Это очень важно, поскольку топ-менеджеры, в большинстве своем, смотрят сразу сюда и только сюда...
#
# Тут важно обратиться к целям, которые были озвучены в самом начале и ответить на все вопросы. Важно оформить все тезисно и с цифрами. Еще важно описать все промежуточные выводы, которых не прописано в целях.
# Вкратце структура такая:
# - как были предобработаны данные(тут важно написать про изменения, если заполнялись пропуски или преобразовывались строки)
# - пройдись по целям и ответь на вопросы
# - добавь промежуточные выводы, которые считаешь нужным отметить
#
# Еще очень важно помнить, для кого ты делаешь проект, в зависимости от этого нужно сделать определенные акценты. В данном случае проект учебный, поэтому нужно ориентироваться по описанию.
#
# Для красивого оформления можешь воспользоваться [Кратким руководством по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/).
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что ты ведешь чек-лист, он помогает ничего не забыть!
#
# </div>
